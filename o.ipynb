# %%
print("hello owrld")
# Out:
# hello owrld

# %% [markdown]
# ### Output operation.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Python provides us with two inbuilt functions to read the input from the keyboard.
#
#         raw_input()
#
#         input()

# %% [markdown]
# raw_input(): This function reads only one line from the standard input and returns it as a String.

# %% [markdown]
# raw_input() : this function is used to get input from user only in the python 2 version.

# %%
# value = raw_input(“Please enter the value: ”);
# print(“Input received from the user is: ”, value)

# %%
value = input("Please enter the value: ")
print("Input received from the user is:", value)
# Out:
# Input received from the user is: HAI HELLO WELCOME

# %% [markdown]
# to check what are python modules present in the working environment.

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.43.1
# C:\Users\VIJAY\AppData\Local\Programs\Python\Python312\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# IPython             asttokens           matplotlib          sunau
# PIL                 asyncio             matplotlib_inline   symtable
# __future__          atexit              mimetypes           sys
# __hello__           audioop             mmap                sysconfig
# __phello__          base64              mmapfile            tabnanny
# _abc                bdb                 mmsystem            tarfile
# _aix_support        binascii            modulefinder        telnetlib
# _ast                bisect              mpl_toolkits        tempfile
# _asyncio            builtins            msilib              test
# ...

# %% [markdown]
# In python 3.9
#
# Python's standard library is extensive and includes modules for various purposes, such as file I/O, regular expressions, networking, databases, GUI development, and more. Some of the core modules in the standard library include:
#
#     os: Operating system interfaces.
#     sys: System-specific parameters and functions.
#     math: Mathematical functions.
#     datetime: Date and time manipulation.
#     random: Generate pseudo-random numbers.
#     re: Regular expression operations.
#     json: JSON encoding and decoding.
#     urllib: URL handling.
#     sqlite3: SQLite database interface.
#     socket: Low-level networking interface.

# %% [markdown]
# print("hello world)

# %%
print("hello")
# Out:
# hello

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.43.1
# IPython             array               math                tabnanny
# __future__          ast                 matplotlib_inline   tarfile
# __hello__           asttokens           mimetypes           telnetlib
# __phello__          asyncio             mmap                tempfile
# _abc                atexit              mmapfile            test
# _aix_support        audioop             mmsystem            textwrap
# _ast                base64              modulefinder        this
# _asyncio            bdb                 msilib              threading
# _bisect             binascii            msvcrt              time
# _blake2             bisect              multiprocessing     timeit
# _bz2                builtins            nest_asyncio        timer
# _codecs             bz2                 netbios             tkinter
# ...

# %%
help('webbrowser')
# Out:
# Help on module webbrowser:
#
# NAME
#     webbrowser - Interfaces for launching and remotely controlling web browsers.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/webbrowser.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         Error
#
#     class Error(builtins.Exception)
#      |  Method resolution order:
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
# ...

# %%
print(help('modules'))
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.43.1
# IPython             array               math                tabnanny
# __future__          ast                 matplotlib_inline   tarfile
# __hello__           asttokens           mimetypes           telnetlib
# __phello__          asyncio             mmap                tempfile
# _abc                atexit              mmapfile            test
# _aix_support        audioop             mmsystem            textwrap
# _ast                base64              modulefinder        this
# _asyncio            bdb                 msilib              threading
# _bisect             binascii            msvcrt              time
# _blake2             bisect              multiprocessing     timeit
# _bz2                builtins            nest_asyncio        timer
# _codecs             bz2                 netbios             tkinter
# ...
